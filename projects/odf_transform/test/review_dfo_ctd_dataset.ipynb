# %%
import pandas as pd
import folium
import numpy as np

import requests
from requests.auth import HTTPBasicAuth
from io import StringIO
from dotenv import dotenv_values

# load config from .env file
config = dotenv_values()

# %%
def erddap_password_protected(query):
    """Download from a password protected erddap"""
    response = requests.get(
        query,                     
        auth = HTTPBasicAuth(config['user'], config['password']),
        stream=True
        )
    if response.status_code == 200:
        return StringIO(response.text) 
    else:
        print(response.text)

# %% [markdown]
# # Review BIO Stations

# %%
# Get list of all the stations and lat/long from the erddap dataset:
url = f"{config['server']}/tabledap/{config['dataset']}.csv?station%2Cid%2Clatitude%2Clongitude&time%3E=1995-07-06T14%3A59%3A10Z&time%3C=2020-12-22T13%3A11%3A30Z&distinct()"
df = pd.read_csv(erddap_password_protected(url),skiprows=[1])

# Get average lat/lon per station and how many files are associated
df_mean_station = df.groupby(['station'])[['latitude','longitude']].mean()
df_station_count = df.groupby(['station'])[['id']].count()

df_stations = df_mean_station.join(df_station_count).rename(columns={'id':'profile_count'})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/jessybarrette/repo/cioos-siooc_data_transform/projects/odf_transform/test/review_dfo_ctd_dataset.ipynb Cell 4' in <cell line: 3>()
#       <a href='vscode-notebook-cell:/Users/jessybarrette/repo/cioos-siooc_data_transform/projects/odf_transform/test/review_dfo_ctd_dataset.ipynb#ch0000002?line=0'>1</a> # Get list of all the stations and lat/long from the erddap dataset:
#       <a href='vscode-notebook-cell:/Users/jessybarrette/repo/cioos-siooc_data_transform/projects/odf_transform/test/review_dfo_ctd_dataset.ipynb#ch0000002?line=1'>2</a> url = f"{config['server']}/tabledap/{config['dataset']}.csv?station%2Cid%2Clatitude%2Clongitude&time%3E=1995-07-06T14%3A59%3A10Z&time%3C=2020-12-22T13%3A11%3A30Z&distinct()"
# ----> <a href='vscode-notebook-cell:/Users/jessybarrette/repo/cioos-siooc_data_transform/projects/odf_transform/test/review_dfo_ctd_dataset.ipynb#ch0000002?line=2'>3</a> df = pd.read_csv(erddap_password_protected(url),skiprows=[1])
#       <a href='vscode-notebook-cell:/Users/jessybarrette/repo/cioos-siooc_data_transform/projects/odf_transform/test/review_dfo_ctd_dataset.ipynb#ch0000002?line=4'>5</a> # Get average lat/lon per station and how many files are associated
#       <a href='vscode-notebook-cell:/Users/jessybarrette/repo/cioos-siooc_data_transform/projects/odf_transform/test/review_dfo_ctd_dataset.ipynb#ch0000002?line=5'>6</a> df_mean_station = df.groupby(['station'])[['latitude','longitude']].mean()
#
# File ~/miniconda3/envs/sensor_network/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     <a href='file:///Users/jessybarrette/miniconda3/envs/sensor_network/lib/python3.9/site-packages/pandas/util/_decorators.py?line=304'>305</a> if len(args) > num_allow_args:
#     <a href='file:///Users/jessybarrette/miniconda3/envs/sensor_network/lib/python3.9/site-packages/pandas/util/_decorators.py?line=305'>306</a>     warnings.warn(
#     <a href='file:///Users/jessybarrette/miniconda3/envs/sensor_network/lib/python3.9/site-packages/pandas/util/_decorators.py?line=306'>307</a>         msg.format(arguments=arguments),
#     <a href='file:///Users/jessybarrette/miniconda3/envs/sensor_network/lib/python3.9/site-packages/pandas/util/_decorators.py?line=307'>308</a>         FutureWarning,
#     <a href='file:///Users/jessybarrette/miniconda3/envs/sensor_network/lib/python3.9/site-packages/pandas/util/_decorators.py?line=308'>309</a>         stacklevel=stacklevel,
#     <a href='file:///Users/jessybarrette/miniconda3/envs/sensor_network/lib/python3.9/site-packages/pandas/util/_decorators.py?line=309'>310</a>     )
# --> <a href='file:///Users/jessybarrette/miniconda3/envs/sensor_network/lib/python3.9/site-packages/pandas/util/_decorators.py?line=310'>311</a> return func(*args, **kwargs)
#
# File ~/miniconda3/envs/sensor_network/lib/python3.9/site-packages/pandas/io/parsers/readers.py:586, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     <a href='file:///Users/jessybarrette/miniconda3/envs/sensor_network/lib/python3.9/site-packages/pandas/io/parsers/readers.py?line=570'>571</a> kwds_defaults = _refine_defaults_read(
#     <a href='file:///Users/jessybarrette/miniconda3/envs/sensor_network/lib/python3.9/site-packages/pandas/io/parsers/readers.py?line=571'>572</a>     dialect,
#     <a href='file:///Users/jessybarrette/miniconda3/envs/sensor_network/lib/python3.9/site-packages/pandas/io/parsers/readers.py?line=572'>573</a>     delimiter,
#    (...)
#     <a href='file:///Users/jessybarrette/miniconda3/envs/sensor_network/lib/python3.9/site-packages/pandas/io/parsers/readers.py?line=581'>582</a>     defaults={"delimiter": ","},
#     <a href='file:///Users/jessybarrette/miniconda3/envs/sensor_network/lib/python3.9/site-packages/pandas/io/parsers/readers.py?line=582'>583</a> )
#     <a href='file:///Users/jessybarrette/miniconda3/envs/sensor_network/lib/python3.9/site-packages/pandas/io/parsers/readers.py?line=583'>584</a> kwds.update(kwds_defaults)
# --> <a href='file:///Users/jessybarrette/miniconda3/envs/sensor_network/lib/python3.9/site-packages/pandas/io/parsers/readers.py?line=585'>586</a> return _read(filepath_or_buffer, kwds)
#
# File ~/miniconda3/envs/sensor_network/lib/python3.9/site-packages/pandas/io/parsers/readers.py:482, in _read(filepath_or_buffer, kwds)
#     <a href='file:///Users/jessybarrette/miniconda3/envs/sensor_network/lib/python3.9/site-packages/pandas/io/parsers/readers.py?line=478'>479</a> _validate_names(kwds.get("names", None))
#     <a href='file:///Users/jessybarrette/miniconda3/envs/sensor_network/lib/python3.9/site-packages/pandas/io/parsers/readers.py?line=480'>481</a> # Create the parser.
# --> <a href='file:///Users/jessybarrette/miniconda3/envs/sensor_network/lib/python3.9/site-packages/pandas/io/parsers/readers.py?line=481'>482</a> parser = TextFileReader(filepath_or_buffer, **kwds)
#     <a href='file:///Users/jessybarrette/miniconda3/envs/sensor_network/lib/python3.9/site-packages/pandas/io/parsers/readers.py?line=483'>484</a> if chunksize or iterator:
#     <a href='file:///Users/jessybarrette/miniconda3/envs/sensor_network/lib/python3.9/site-packages/pandas/io/parsers/readers.py?line=484'>485</a>     return parser
#
# File ~/miniconda3/envs/sensor_network/lib/python3.9/site-packages/pandas/io/parsers/readers.py:811, in TextFileReader.__init__(self, f, engine, **kwds)
#     <a href='file:///Users/jessybarrette/miniconda3/envs/sensor_network/lib/python3.9/site-packages/pandas/io/parsers/readers.py?line=807'>808</a> if "has_index_names" in kwds:
#     <a href='file:///Users/jessybarrette/miniconda3/envs/sensor_network/lib/python3.9/site-packages/pandas/io/parsers/readers.py?line=808'>809</a>     self.options["has_index_names"] = kwds["has_index_names"]
# --> <a href='file:///Users/jessybarrette/miniconda3/envs/sensor_network/lib/python3.9/site-packages/pandas/io/parsers/readers.py?line=810'>811</a> self._engine = self._make_engine(self.engine)
#
# File ~/miniconda3/envs/sensor_network/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1040, in TextFileReader._make_engine(self, engine)
#    <a href='file:///Users/jessybarrette/miniconda3/envs/sensor_network/lib/python3.9/site-packages/pandas/io/parsers/readers.py?line=1035'>1036</a>     raise ValueError(
#    <a href='file:///Users/jessybarrette/miniconda3/envs/sensor_network/lib/python3.9/site-packages/pandas/io/parsers/readers.py?line=1036'>1037</a>         f"Unknown engine: {engine} (valid options are {mapping.keys()})"
#    <a href='file:///Users/jessybarrette/miniconda3/envs/sensor_network/lib/python3.9/site-packages/pandas/io/parsers/readers.py?line=1037'>1038</a>     )
#    <a href='file:///Users/jessybarrette/miniconda3/envs/sensor_network/lib/python3.9/site-packages/pandas/io/parsers/readers.py?line=1038'>1039</a> # error: Too many arguments for "ParserBase"
# -> <a href='file:///Users/jessybarrette/miniconda3/envs/sensor_network/lib/python3.9/site-packages/pandas/io/parsers/readers.py?line=1039'>1040</a> return mapping[engine](self.f, **self.options)
#
# File ~/miniconda3/envs/sensor_network/lib/python3.9/site-packages/pandas/io/parsers/c_parser_wrapper.py:51, in CParserWrapper.__init__(self, src, **kwds)
#      <a href='file:///Users/jessybarrette/miniconda3/envs/sensor_network/lib/python3.9/site-packages/pandas/io/parsers/c_parser_wrapper.py?line=47'>48</a> kwds["usecols"] = self.usecols
#      <a href='file:///Users/jessybarrette/miniconda3/envs/sensor_network/lib/python3.9/site-packages/pandas/io/parsers/c_parser_wrapper.py?line=49'>50</a> # open handles
# ---> <a href='file:///Users/jessybarrette/miniconda3/envs/sensor_network/lib/python3.9/site-packages/pandas/io/parsers/c_parser_wrapper.py?line=50'>51</a> self._open_handles(src, kwds)
#      <a href='file:///Users/jessybarrette/miniconda3/envs/sensor_network/lib/python3.9/site-packages/pandas/io/parsers/c_parser_wrapper.py?line=51'>52</a> assert self.handles is not None
#      <a href='file:///Users/jessybarrette/miniconda3/envs/sensor_network/lib/python3.9/site-packages/pandas/io/parsers/c_parser_wrapper.py?line=53'>54</a> # Have to pass int, would break tests using TextReader directly otherwise :(
#
# File ~/miniconda3/envs/sensor_network/lib/python3.9/site-packages/pandas/io/parsers/base_parser.py:222, in ParserBase._open_handles(self, src, kwds)
#     <a href='file:///Users/jessybarrette/miniconda3/envs/sensor_network/lib/python3.9/site-packages/pandas/io/parsers/base_parser.py?line=217'>218</a> def _open_handles(self, src: FilePathOrBuffer, kwds: dict[str, Any]) -> None:
#     <a href='file:///Users/jessybarrette/miniconda3/envs/sensor_network/lib/python3.9/site-packages/pandas/io/parsers/base_parser.py?line=218'>219</a>     """
#     <a href='file:///Users/jessybarrette/miniconda3/envs/sensor_network/lib/python3.9/site-packages/pandas/io/parsers/base_parser.py?line=219'>220</a>     Let the readers open IOHandles after they are done with their potential raises.
#     <a href='file:///Users/jessybarrette/miniconda3/envs/sensor_network/lib/python3.9/site-packages/pandas/io/parsers/base_parser.py?line=220'>221</a>     """
# --> <a href='file:///Users/jessybarrette/miniconda3/envs/sensor_network/lib/python3.9/site-packages/pandas/io/parsers/base_parser.py?line=221'>222</a>     self.handles = get_handle(
#     <a href='file:///Users/jessybarrette/miniconda3/envs/sensor_network/lib/python3.9/site-packages/pandas/io/parsers/base_parser.py?line=222'>223</a>         src,
#     <a href='file:///Users/jessybarrette/miniconda3/envs/sensor_network/lib/python3.9/site-packages/pandas/io/parsers/base_parser.py?line=223'>224</a>         "r",
#     <a href='file:///Users/jessybarrette/miniconda3/envs/sensor_network/lib/python3.9/site-packages/pandas/io/parsers/base_parser.py?line=224'>225</a>         encoding=kwds.get("encoding", None),
#     <a href='file:///Users/jessybarrette/miniconda3/envs/sensor_network/lib/python3.9/site-packages/pandas/io/parsers/base_parser.py?line=225'>226</a>         compression=kwds.get("compression", None),
#     <a href='file:///Users/jessybarrette/miniconda3/envs/sensor_network/lib/python3.9/site-packages/pandas/io/parsers/base_parser.py?line=226'>227</a>         memory_map=kwds.get("memory_map", False),
#     <a href='file:///Users/jessybarrette/miniconda3/envs/sensor_network/lib/python3.9/site-packages/pandas/io/parsers/base_parser.py?line=227'>228</a>         storage_options=kwds.get("storage_options", None),
#     <a href='file:///Users/jessybarrette/miniconda3/envs/sensor_network/lib/python3.9/site-packages/pandas/io/parsers/base_parser.py?line=228'>229</a>         errors=kwds.get("encoding_errors", "strict"),
#     <a href='file:///Users/jessybarrette/miniconda3/envs/sensor_network/lib/python3.9/site-packages/pandas/io/parsers/base_parser.py?line=229'>230</a>     )
#
# File ~/miniconda3/envs/sensor_network/lib/python3.9/site-packages/pandas/io/common.py:609, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     <a href='file:///Users/jessybarrette/miniconda3/envs/sensor_network/lib/python3.9/site-packages/pandas/io/common.py?line=601'>602</a>     raise ValueError(
#     <a href='file:///Users/jessybarrette/miniconda3/envs/sensor_network/lib/python3.9/site-packages/pandas/io/common.py?line=602'>603</a>         f"Invalid value for `encoding_errors` ({errors}). Please see "
#     <a href='file:///Users/jessybarrette/miniconda3/envs/sensor_network/lib/python3.9/site-packages/pandas/io/common.py?line=603'>604</a>         + "https://docs.python.org/3/library/codecs.html#error-handlers "
#     <a href='file:///Users/jessybarrette/miniconda3/envs/sensor_network/lib/python3.9/site-packages/pandas/io/common.py?line=604'>605</a>         + "for valid values."
#     <a href='file:///Users/jessybarrette/miniconda3/envs/sensor_network/lib/python3.9/site-packages/pandas/io/common.py?line=605'>606</a>     )
#     <a href='file:///Users/jessybarrette/miniconda3/envs/sensor_network/lib/python3.9/site-packages/pandas/io/common.py?line=607'>608</a> # open URLs
# --> <a href='file:///Users/jessybarrette/miniconda3/envs/sensor_network/lib/python3.9/site-packages/pandas/io/common.py?line=608'>609</a> ioargs = _get_filepath_or_buffer(
#     <a href='file:///Users/jessybarrette/miniconda3/envs/sensor_network/lib/python3.9/site-packages/pandas/io/common.py?line=609'>610</a>     path_or_buf,
#     <a href='file:///Users/jessybarrette/miniconda3/envs/sensor_network/lib/python3.9/site-packages/pandas/io/common.py?line=610'>611</a>     encoding=encoding,
#     <a href='file:///Users/jessybarrette/miniconda3/envs/sensor_network/lib/python3.9/site-packages/pandas/io/common.py?line=611'>612</a>     compression=compression,
#     <a href='file:///Users/jessybarrette/miniconda3/envs/sensor_network/lib/python3.9/site-packages/pandas/io/common.py?line=612'>613</a>     mode=mode,
#     <a href='file:///Users/jessybarrette/miniconda3/envs/sensor_network/lib/python3.9/site-packages/pandas/io/common.py?line=613'>614</a>     storage_options=storage_options,
#     <a href='file:///Users/jessybarrette/miniconda3/envs/sensor_network/lib/python3.9/site-packages/pandas/io/common.py?line=614'>615</a> )
#     <a href='file:///Users/jessybarrette/miniconda3/envs/sensor_network/lib/python3.9/site-packages/pandas/io/common.py?line=616'>617</a> handle = ioargs.filepath_or_buffer
#     <a href='file:///Users/jessybarrette/miniconda3/envs/sensor_network/lib/python3.9/site-packages/pandas/io/common.py?line=617'>618</a> handles: list[Buffer]
#
# File ~/miniconda3/envs/sensor_network/lib/python3.9/site-packages/pandas/io/common.py:396, in _get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode, storage_options)
#     <a href='file:///Users/jessybarrette/miniconda3/envs/sensor_network/lib/python3.9/site-packages/pandas/io/common.py?line=393'>394</a> if not is_file_like(filepath_or_buffer):
#     <a href='file:///Users/jessybarrette/miniconda3/envs/sensor_network/lib/python3.9/site-packages/pandas/io/common.py?line=394'>395</a>     msg = f"Invalid file path or buffer object type: {type(filepath_or_buffer)}"
# --> <a href='file:///Users/jessybarrette/miniconda3/envs/sensor_network/lib/python3.9/site-packages/pandas/io/common.py?line=395'>396</a>     raise ValueError(msg)
#     <a href='file:///Users/jessybarrette/miniconda3/envs/sensor_network/lib/python3.9/site-packages/pandas/io/common.py?line=397'>398</a> return IOArgs(
#     <a href='file:///Users/jessybarrette/miniconda3/envs/sensor_network/lib/python3.9/site-packages/pandas/io/common.py?line=398'>399</a>     filepath_or_buffer=filepath_or_buffer,
#     <a href='file:///Users/jessybarrette/miniconda3/envs/sensor_network/lib/python3.9/site-packages/pandas/io/common.py?line=399'>400</a>     encoding=encoding,
#    (...)
#     <a href='file:///Users/jessybarrette/miniconda3/envs/sensor_network/lib/python3.9/site-packages/pandas/io/common.py?line=402'>403</a>     mode=mode,
#     <a href='file:///Users/jessybarrette/miniconda3/envs/sensor_network/lib/python3.9/site-packages/pandas/io/common.py?line=403'>404</a> )
#
# ValueError: Invalid file path or buffer object type: <class 'NoneType'>

# %%
# Retrieve reference stations from 
df_ref = pd.read_csv('../reference_stations.csv').set_index('station').drop(columns=['group','comments','depth_m']).add_prefix('ref_')

# %%
# Combine reference stations to the mean location
df = df_stations.join(df_ref)
# df.to_csv('DFO-BIO_station_mean_location.csv')
df
# Out:
#           latitude  longitude  profile_count  ref_longitude  ref_latitude
# station
# AR7W01   53.676095 -55.550619             21      -55.55000      53.68000
# AR7W02   53.795911 -55.437044             18      -55.43667      53.79667
# AR7W03   53.987005 -55.250330             20      -55.25000      53.98833
# AR7W04   54.220464 -55.025759             22      -55.02333      54.22000
# AR7W05   54.490000 -54.754295             22      -54.75667      54.49167
# ...            ...        ...            ...            ...           ...
# YL06     43.398540 -68.663020             10      -68.66400      43.39900
# YL07     43.328800 -69.106780             10      -69.10600      43.32800
# YL08     43.258300 -69.557660             10      -69.55700      43.25800
# YL09     43.186500 -70.009260             10      -70.01000      43.18600
# YL10     43.155767 -70.272300              6      -70.27200      43.15700
#
# [201 rows x 5 columns]

# %%
# Show on a map
m = folium.Map(location=[df['latitude'].mean(),df['longitude'].mean()],zoom_start=4)
for station, row in df.iterrows():
    if -90< row['ref_latitude']<90 :
        folium.Marker(location=[row['ref_latitude'],row['ref_longitude']],popup=station).add_to(m)
    else:
        folium.Marker(location=[row['latitude'],row['longitude']],popup=f"{station}: {int(row['profile_count'])} files related",icon=folium.Icon(color="red", icon="info-sign"),).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script&gt;L_PREFER_CANVAS=false; L_NO_TOUCH=false; L_DISABLE_3D=false;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.4.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.4.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css&quot;/&gt;
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#
#     &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#         initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#     &lt;style&gt;#map_c9970d929c0fe62ed500c9526d68b8c2 {
#         position: relative;
#         width: 100.0%;
#         height: 100.0%;
#         left: 0.0%;
#         top: 0.0%;
#         }
#     &lt;/style&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;div class=&quot;folium-map&quot; id=&quot;map_c9970d929c0fe62ed500c9526d68b8c2&quot; &gt;&lt;/div&gt;
# &lt;/body&gt;
# &lt;script&gt;
#
#
#         var bounds = null;
#
#
#     var map_c9970d929c0fe62ed500c9526d68b8c2 = L.map(
#         &#x27;map_c9970d929c0fe62ed500c9526d68b8c2&#x27;, {
#         center: [48.590236742979116, -58.44616969721655],
#         zoom: 4,
#         maxBounds: bounds,
#         layers: [],
#         worldCopyJump: false,
#         crs: L.CRS.EPSG3857,
#         zoomControl: true,
#         });
#
#
#
#     var tile_layer_d3ac0ebd3840675ab60ec3cf483be634 = L.tileLayer(
#         &#x27;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&#x27;,
#         {
#         &quot;attribution&quot;: null,
#         &quot;detectRetina&quot;: false,
#         &quot;maxNativeZoom&quot;: 18,
#         &quot;maxZoom&quot;: 18,
#         &quot;minZoom&quot;: 0,
#         &quot;noWrap&quot;: false,
#         &quot;opacity&quot;: 1,
#         &quot;subdomains&quot;: &quot;abc&quot;,
#         &quot;tms&quot;: false
# }).addTo(map_c9970d929c0fe62ed500c9526d68b8c2);
#
#         var marker_b858a5d81440d427dcc2ec05fdc18b53 = L.marker(
#             [53.68, -55.55],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(map_c9970d929c0fe62ed500c9526d68b8c2);
#
#
#             var popup_bb23ff73e93c083ab7862dd85c047d58 = L.popup({maxWidth: &#x27;100%&#x27;
#
#             });
#
#
#                 var html_c1e85715e893906e913953b75ce4dcab = $(`&lt;div id=&quot;html_c1e85715e893906e913953b75ce4dcab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;AR7W01&lt;/div&gt;`)[0];
#                 popup_bb23ff73e93c083ab7862dd85c047d58.setContent(html_c1e85715e893906e913953b75ce4dcab);
#
#
#             marker_b858a5d81440d427dcc2ec05fdc18b53.bindPopup(popup_bb23ff73e93c083ab7862dd85c047d58)
#             ;
#
#
#
#
#         var marker_caf77183bf8c10ddf352198915fb9090 = L.marker(
#             [53.79667, -55.43667],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(map_c9970d929c0fe62ed500c9526d68b8c2);
#
#
#             var popup_5545e5942dd2022cd3d87def672aee21 = L.popup({maxWidth: &#x27;100%&#x27;
#
#             });
#
#
#                 var html_181019d2d1b6aa1f5a251f51abedb8f8 = $(`&lt;div id=&quot;html_181019d2d1b6aa1f5a251f51abedb8f8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;AR7W02&lt;/div&gt;`)[0];
#                 popup_5545e5942dd2022cd3d87def672aee21.setContent(html_181019d2d1b6aa1f5a251f51abedb8f8);
#
#
#             marker_caf77183bf8c10ddf352198915fb9090.bindPopup(popup_5545e5942dd2022cd3d87def672aee21)
#             ;
#
#
#
#
#         var marker_e70655d054da1b7af0d437aaa0a828e1 = L.marker(
#             [53.98833, -55.25],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(map_c9970d929c0fe62ed500c9526d68b8c2);
#
#
#             var popup_77177fb74fdf172ac6789c3fd3aa6a81 = L.popup({maxWidth: &#x27;100%&#x27;
#
#             });
#
#
#                 var html_8b245922c593fc03503cb8da26034553 = $(`&lt;div id=&quot;html_8b245922c593fc03503cb8da26034553&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;AR7W03&lt;/div&gt;`)[0];
#                 popup_77177fb74fdf172ac6789c3fd3aa6a81.setContent(html_8b245922c593fc03503cb8da26034553);
#
#
#             marker_e70655d054da1b7af0d437aaa0a828e1.bindPopup(popup_77177fb74fdf172ac6789c3fd3aa6a81)
#             ;
#
#
#
#
#         var marker_41000ae149f84b9db1bf9bfe15a6c30a = L.marker(
#             [54.22, -55.02333],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(map_c9970d929c0fe62ed500c9526d68b8c2);
#
#
#             var popup_6e41375135ad504a103f32562b0ac9a4 = L.popup({maxWidth: &#x27;100%&#x27;
#
#             });
#
#
#                 var html_b7dc45bd510d39d4a02f20a57d57f6c4 = $(`&lt;div id=&quot;html_b7dc45bd510d39d4a02f20a57d57f6c4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;AR7W04&lt;/div&gt;`)[0];
#                 popup_6e41375135ad504a103f32562b0ac9a4.setContent(html_b7dc45bd510d39d4a02f20a57d57f6c4);
#
#
#             marker_41000ae149f84b9db1bf9bfe15a6c30a.bindPopup(popup_6e41375135ad504a103f32562b0ac9a4)
#             ;
#
#
#
#
#         var marker_56b6712b018306d0cdd551ff20b4fb5d = L.marker(
#             [54.49167, -54.75667],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(map_c9970d929c0fe62ed500c9526d68b8c2);
#
#
#             var popup_e13f55d2b87a34acc87f50d2641a4873 = L.popup({maxWidth: &#x27;100%&#x27;
#
#             });
#
#
#                 var html_2d119293bf7fee6e47e40a70cf639835 = $(`&lt;div id=&quot;html_2d119293bf7fee6e47e40a70cf639835&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;AR7W05&lt;/div&gt;`)[0];
#                 popup_e13f55d2b87a34acc87f50d2641a4873.setContent(html_2d119293bf7fee6e47e40a70cf639835);
#
#
#             marker_56b6712b018306d0cdd551ff20b4fb5d.bindPopup(popup_e13f55d2b87a34acc87f50d2641a4873)
#             ;
#
#
#
#
#         var marker_96ada760a1e919ae4cd17b7909c44baa = L.marker(
#             [54.76167, -54.48667],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(map_c9970d929c0fe62ed500c9526d68b8c2);
#
#
#             var popup_a86b5ab25a7a4fc53f5f4339a1955e37 = L.popup({maxWidth: &#x27;100%&#x27;
#
#             });

# %%
# get list of stations for which we don't have a reference lat/lon
df.query(' not -90<ref_latitude<90')
# Out:
#            latitude  longitude  profile_count  ref_longitude  ref_latitude
# station
# LC09      46.871300 -58.635400              2            NaN           NaN
# LC14      45.732100 -56.851900              2            NaN           NaN
# LC15      45.346700 -56.953100              2            NaN           NaN
# LC20      45.360500 -56.673700              2            NaN           NaN
# LC23      45.975400 -57.647000              2            NaN           NaN
# LC24      46.635900 -57.922100              2            NaN           NaN
# LC25      46.630200 -57.632800              2            NaN           NaN
# Prince 5  44.932011 -66.849721            440            NaN           NaN

# %% [markdown]
# # Review ERDDAP

# %%
variables = [
    ("PSLTZZ01",-10),
    ("PSLTZZ02",-10),
    ("TEMPP682",-10),
    ("CNDCST01",-1),
    ("CNDCST02",-1),
    ("DOXYZZ01",-10),
    ("DOXYZZ02",-10),
    ("CDOMZZ01",-1),
    ("CDOMZZ02",-1),
    ("CPHLPR01",-10),
    ("CPHLPR02",-10),
    ("IRRDUV01",-10),
]

df_bad_values = pd.DataFrame()
for var, lim in variables:
    condition = f"{var}<{lim}"
    try:
        df_temp = pd.read_csv(erddap_password_protected(f"{config['server']}/tabledap/{config['dataset']}.csv?id&{condition}&distinct()"),index_col='id')
    except:
        print(f'failed condition {condition}')
        continue
    df_temp[condition] = True
    df_bad_values = df_bad_values.join(df_temp, how='outer')

# Output result to a csv
df_bad_values.replace({pd.NA:False}).to_csv('bad_values.csv')
print(f"{len(df_bad_values)} files seems to accept the conditions.")
